# %%
from datetime import date 

from ds_2019_03_hw01_part1.scrappers.scrapper import Scrapper
from ds_2019_03_hw01_part1.storages.dataframe_storage import DataFrameStorage
from ds_2019_03_hw01_part1.core.constants import IMDB_TITLE_TYPES

storage = DataFrameStorage(IMDB_TITLE_TYPES)

release_date_from = date(1850, 1, 1)
release_date_to   = date(1899, 12, 31)
limit = 1453

scrapper = Scrapper()
scrapper.scrap_process(storage, release_date_from=release_date_from, release_date_to=release_date_to, limit=limit)

storage.data_frame.head(5)
# Out:
#                                        title  year               link  rating  \
# 0                              Замок дьявола  1896  /title/tt0000091/     6.7
# 1  Прибытие поезда на вокзал города Ла-Сьота  1896  /title/tt0000012/     7.4
# 2                      Сцена в саду Роундхэй  1888  /title/tt0392728/     7.5
# 3                                 Карменсита  1894  /title/tt0000001/     5.8
# 4                             Транзит Венеры  1874  /title/tt3155794/     7.0
#
#   votes                       genre runtime
# 0  2359               Short, Horror   3 min
# 1  9077  Documentary, Short, Action   1 min
# 2  4872          Documentary, Short   1 min
# 3  1507          Documentary, Short   1 min
# 4   930          Documentary, Short   1 min

# %%
display(storage.data_frame)
display(storage.data_frame.head())
display(storage.data_frame.describe())
# Out:
#                                                   title      year  \
# 0                                         Замок дьявола      1896
# 1             Прибытие поезда на вокзал города Ла-Сьота      1896
# 2                                 Сцена в саду Роундхэй      1888
# 3                                            Карменсита      1894
# 4                                        Транзит Венеры      1874
# 5                               Луна всего лишь в метре      1898
# 6                            Sallie Gardner at a Gallop      1878
# 7                      Выход рабочих с фабрики 'Люмьер'      1895
# 8                                              Rapunzel      1897
# 9                                         Дело Дрейфуса      1899
# 10                                  Политый поливальщик      1895
# 11                                         Буйвол бежит      1883
# 12                                              Золушка      1899
# ...
